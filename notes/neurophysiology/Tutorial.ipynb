# %% [markdown]
# ## Tutorial questions: Synaptic transmission.
#
# - 1 List the basic steps (pre and postsynaptic) of synaptic
# transmission at chemical synapses (No more than 10 items).
#
# > [Pre-synapticaly ](../neurophisiology/neurophysiology.ipynb#l4p4)
# 3. AP
# 4. $Ca^{2+}$ influx (**slow process**)
# 5. Activation of SNARE complex
# 6. Release of NT in vesicle
# >
# > [Postsynaptically](../neurophisiology/neurophysiology.ipynb#l5)
# 7. Binding to NT receptors
# 8. Activation of ligand depended channels (de- or hyper- polarization), G-protein activation
# 9. Effect of second messedger (depends on G-proten type) (***slow process*)
# 10. Re-uptake by glia, pre-synapse and post-synapse by NT transporters to prevent reactivation of NT receptors
#
# - 2 Why do calcium channels open when an action potential
# invades the terminal?
#
# > Because they are **voltage dependent** ($-30 mV$)
#
# - 3 What is the effect of decreased extracellular calcium
# concentration on synaptic transmission? Specifically, how will be
# modified 1) the postsynaptic potential (PSP) evoked by
# stimulation of the presynaptic cell, and 2) the spontaneous
# miniature psps?
#
# > 1. The ampliture of **evoked**-PSP will decrease (less EPSP or less IPSP depending on type of NT and NT receptors)
# > 2. The amplitude of **mini-PSP** will be the same. But the frequency may decrease (if vesicle is near $Ca^{2+}$ channels)
# > So we can conclude that the $Ca^{2+}$ concentration effect on probability of release, not size of PSP evoked by one vesicle.
#
# - 4 In which phase of action potential invasion of the presynaptic terminal will the maximum calcium influx occur?
# Check one: During the
#  - a) early rising
#  - b) late rising
#  - c) peak
#  - d) repolarization
#
# phase of the action potential. Explain why!
#
# > I think d) because the $Ca^{2+}$ influx is delayed. During first stage of AP the $E_m$ is  $ +40 mV$ (that is near enough to $E_{Ca}$) so the driving force is small and $Ca^{2+}$ influx is small too. But the amount of open channel is increased. Than during repolarization $E_m - E_{Ca}$ becames bigger, and the $g$ is already near $g_max$, because of the opening of channels during first stage of AP. So we have big driving force => $Ca^{2+}$ influx
#
#
# - 5 Is the sodium/potassium influx associated to the presynaptic
# action potential necessary for neurotransmitter release? Which
# results support your response? Indicate a procedure to induce
# neurotransmitter release experimentally in an in vitro preparation
# if action potentials are blocked by TTX.
#
# > [Answer](../neurophisiology/neurophysiology.ipynb#l4p3)
# > No they are not necessary. During the TTX and TEA we
# see the **PSP**  response.
# > <img  src="images/l4g9.png"/>
#
# > - We use large SQUID fiber. And electrode to inject current, so we have depolariation with out AP, and $Na^+$ influx.
# > - Also one can change the $[K^+]$ to increase $E_K$ and therefore increase $E_{reversal}$ t make it bigger than $E_{threshold}$.
# > - $Ca^{2+}$ injected inside the cell
#
# > - patch clamp cell-attached (we can change the potential of terminale membrane)
#
# - 6 Explain the origin and nature of miniature synaptic potentials. (more about post synaptic side)
#
# > - When one vesicle release spontaneously, the released NT induces minis. Can be caused by spontaneous opening of $Ca^{2+}$ channels or intracellular storage (buffers) of $Ca^{2+}$ or fusion of vesicle without $Ca^{2+}$
#
# > - Passive -> origin in post-synaptic side.
# > - The same shape as evoked. Evoked is equal N*minis, so we conclude that mini is due to release of one vesicles
#
# - 7 If the probability of neurotransmitter release is increased, do
# you expect to see an increase in:
#  - a) The frequency of miniature psps?
#  - b) The amplitude of miniature psps?
#  - c) Why?
#
# > - The frequency will be increased, if the vesicles of minis are *the same minis*.
# > - Whereas amplitude of minis doesn't depend of probability of release, but depend on size of one vesicle
#
#
# - 8 Regarding synaptic plasticity: if depression at a particular
# synapse is correlated with a reduction of the frequency of
# miniature events, the most probable locus of expression is pre or
# postsynaptic? Explain why!
#
# > - pre synaptic, because the bigger frequency of mini means that number of spontaneous release per second in **axon terminal** increased. In can be caused by increased probability of spontaneous $Ca^{2+}$ influx.
# > - post synaptically it can happend only if we silend some synapse (**minor**)
#
# - 9 List three molecules of the “release machinery” and explain
# their postulated role in neurotransmitter release.
#
# > 1. Synaptotagmin - binding of $Ca^{2+}$ and fusion of vesicle and cell membranes
# > 2. Synaptobrevin (vesicle) + Syntaxin (membrane) + SNAP-25 - docking of the vesicle
# > 3. Active zone protein complex (RIM, Munc13)
#
# - 10 What is a reversal potential?
#
# > It is potential when net current throuth membrane is equal to zero. In the case of one ion $E_{reversal}=E_{Nerst}$. In case of several ions $E_{reversal}= E_{GHK}$ .
#
# - 11 Are synaptic potentials conducted actively or passively? Explain!
#
# > They are conducted passively. PSP in dendrites conducted without **voltage dependent** channels.
#
# - 12 What is a ligand-gated channel? Do you know any ligand and voltage dependent channel/s?
#
# > Ligand-gated channel is a channel that open due to binding of some ligand. For example all ionotropic receptors are ligand (NT) depended. NMDA-R needs glutamate and glycine (ligand dependent) and need pre-depolarization (voltage depended) .
#
# - 13 Explain the differences between ionotropic and metabotropic
# receptors!
#
# > - ionotropic receptors - ligand gated **ion channels**, the are fast, and short -lasting.
# > - metabotropic receptors - ligand binding cause conformational change and activated G-protein, that can influence ion channels and second messenger proteins.
#
# - 14 Refer to slide #16 of the lecture synaptic transmsission 2
# (single channel recordings).
#   - How were these recording obtained?
#   - Based on these recordings, how would you calculate the conductance of a single channel of Ach.
#   - Which other information do you need to calculate the number of channels opened by 1 quantum of ACh?
# > - Patch-clump in outside-out regime. Voltage clump
# > - I will divide the recorded current by voltage (we have measure current in many different voltages) the slope of the fited line is channel conductance
# > - I need to know the current PSC and voltage PSP during minis PSP
#
# - 15 Which is the reversal potential of NMDA currents.
#
# >  It is not selective cation channel, so the reversal potential is near $0 mV$
#
# - 16 Which ions can permeate NMDA channels?
#
# > Cations ($K^+$, $Ca^{2+}$, $Na^{+}$, ... )
#
# - 17 Describe and explain the mechanism of NMDA currents
# voltage dependence.
#
# > NMDA pore is blocked by $Mg^{2+}$ (flickering, the stage or closed and opend) and to be open $Mg^{2+}$ has to be removed from NMDA. During depolarization (usually via AMPA channels) $Mg^{2+}$ is removed, so the channel is active (if Glu and Gly are binded).
#
# - 18 A glutamatergic EPSC is recorded at -80 mV. Indicate how
# amplitude and duration will be affected by :
# - a) Reducing the sodium extracellular concentration from 130 to 40
# mM
#
#
# >Amplitude: smaller
#
# >Duration: the same
#
# >In one sentence support your response: Smaller extracellular concentration diminishs $E_{Nerst}$ for $Na^+$ -> decreased driving force -> less current flow
#
#  - b) Depolarizing the membrane potential of the postsynaptic
# neuron to -40 mV.
#
# >Amplitude: smaller (NMDA active, but it is not enough) or (no change)
#
# >Duration: longer
#
# >In one sentence support your response: smaller difference -> driving force. Some NMDA receptors active -> long duration
#
#  - Indicate the effect of application of the NMDA antagonist AP5 on
# the EPSC recorded at
#    - c) -80 mV.
#
# >Amplitude: the same
#
# >Duration: the same
#
# >In one sentence support your response: NMDA is already blocked by $Mg^{2+}$
#
#    - d) -40 mV
#
# >Amplitude: less
#
# >Duration: less
#
# >In one sentence support your response: We block NMDA current, so no more long component and less amplitude (maybe small effect)
#
#  - Indicate the effect of reducing the extracellular magnesium
# concentration on the EPSC recorded at
#
# - e- -80 mV
#
# >Amplitude: bigger
#
# >Duration: bigger
#
# >In one sentence support your response: NMDA is not blocked by $Mg^{2+}$ so we have to add it to AMPA currents.
#
# - f- -40 mV
#
# >Amplitude: bigger
#
# >Duration: bigger
#
# >In one sentence support your response: Not all NMDA were unblocked from $Mg^{2+}$. So after deleting $Mg^{2+}$ mare current inside the cell
#
# - 19 In an experiment using whole cell attached configuration to
# record from neurons in slices taken from neonate animals it is
# shown:
# that stimulation of an afferent pathway **triggered spikes** with short
# latency,
# and application of a GABA$_A$ antagonist **abolished** the response.
# Intracellular recordings of the same cell with sharp electrodes
# showed that the resting membrane potential of the neuron was $-65mV$ and that the stimulation of the afferent pathway evoked a
# fast depolarizing postsynaptic potentials that reached threshold
# and triggered spikes. Under these experimental conditions the
# reversal potential of the PSP was found to be -35 mV.
# Given these results indicate:
#   - a) Is the pathway B inhibitory or excitatory? Give arguments that
# support your statement.
#   - b) Which type of ions can permeate the GABA$_A$ ligand-gated
# channels and what is the usual reversal potential of GABA$_A$ PSPs
# in adult animals?
#   - c) Put forward a hypothesis that could explain the results of the
# present experiment in neonate animals.
#
# > - Pathway is excitatory, because the reversal potantion of is bigger than the threshold
# > - The GABA$_A$ ligand-gated
# channels are permeable to anions. ($Cl^-$) Usually reversal potential is near $E_{Cl} = -75 mV$
# > - I think, that intracellular concentration of $Cl^-$ is bigger, because there is already expressed a lot of  NKCC transporters(decrease $[Cl^-]$), whereas NKK transporters (decrease $[Cl^-]$) are not expressed yet -> It depolize the cell.
#
#
# - 20 In a two neuron circuit, neuron A synapses onto neuron B.
# The PSC (postsynaptic current) induced in B by activation of the
# neuron A at $-70 mV$ (holding potential) was $-100 pA.$ The average
# amplitude of miniature PSCs was -10pA. After pairing repetitively
# the activation of neuron A with the activation of neuron B (under
# current clamp) the amplitude of the PSC changed to $-200 pA$ (at -
# 70mV) and remained at this level for at least 3 hours. The
# average amplitude of the miniature PSCs after the pairing
# protocol was increased to $-20 pA.$
#   - a) Which type of synaptic plasticity (according to the time
# course, sign, etc) was induced in this experiment? Justify your
# answer in one short statement.
#
# > Long term plasticity. Potentiantion (? Because we have bigger current)
#
# - b) Define the following terms in one short statement:
#       - quantal content: $M$ - average amount of vesicles
#       - quantal size: $q$ - PSP of one vesicle (response to one quantum)
# - c) Calculate the quantal content before and after pairing in this
# synapse. Justify your answer in one short statement.
#       - Before pairing: 10
#       - After pairing: 10
#
# > The content is equal $M=\frac{PSC}{mPSC}$
#
#   - d) According to your answer to (c), where do you think the
# expression mechanism of this form of plasticity is located: on the
# pre- or the post-synaptic side? Briefly support your statement.
#
# >  post-sinaptically  because number of the vesicles is the same.( And the )
#
#   - e) Which mechanism of expression could explain the results of
# this experiment. Justify your answer in one short statement.
#
# > More active channels, activation of one channel gives bigger effect
#
# - 21 Regarding short term plasticity:
#    - a) Name and describe three forms of short term plasticity.
#    - b) What is known about the corresponding cellular mechanisms?
#    - c) Explain postulated functions of short term plasticity?
#
# > - STF - short term facilitation, STD - sort term depression, PTP - post titanic potentiation.
# > - STF - residual $Ca^{2+}$, STD - many variants  (e.g. presynaptic inhibition ), PTP - also residual $Ca^{2+}$ ??
# > - There are several functions:
# >   - filtering  (different neurons get different signal from the same axon depending of their cell type)
# >   - spatial-temporal transformation (use different time to travel thouth axon to facilitate some spacial location and diminish others, by different interneurons)
# >   - selective reading (STF synapses sensitive to average frequience, where as STD, sensitive to changes in presynaptic firing rate)
#
# - 22 Calcium sensors are proposed to be involved in
# neurotransmitter release and short term facilitation. Discuss the
# arguments supporting the idea that the calcium sensor for
# neurotransmitter release and facilitation are different.
#
# > There is correlation between Calcium changes and STF. But the sensor is not synaptotagmin because **scale** and **shape** of $Ca^{2+}$ dependence are different
# > <img  src="images/l6g13.png"/>
#
# - 23 Describe induction and expression of long term potentiation at
# synapses of Schaffer collaterals onto CA1 pyramids in
# hippocampus. Discuss whether this type of plasticity is ‘Hebbian
# or not!
#
# > - Induction(what triggers the LTP): there is $Ca^{2+}$ influx due to activation of NMDA receptors via depolarization.-> Second mess. processes.
# > - Expression(what supports bigger PSP during LTP):
#      - Early phase - higher AMDA conductance. New AMDA receptors.
#      - Late phase. Requires new protein synthesis. Turn on silent proteins. New contacts.
# > - synapses of Schaffer collaterals is Hebbian type of placticity.
#      - paired activity of the pre-synaptic and postsynaptic neuron
#      - input specific: only the synapses activated are modified
#      - homosynaptic involves only one type of synapses
#      - What is the difference between homosynaptic and input specific plasticity?
#
# - 24 Consider the following experimental preparation: Using brain
# slices maintained in vitro a neuron is recorded using **whole cell**
# patch configuration and its response to the stimulation of two
# different pathways contacting this neuron, named A and B, is
# obtained. Pathway **A is glutamatergic** and pathway **B is
# GABAergic**. Stimulation of pathway **B ilonduces a response** that
# can be **completely blocked by GABA$_A$ receptor antagonists**.
# The $E_{Na^+}$ is $+70 mV$, the $E_{K^+}$ is $-100 mV$, the $E_{Cl^-}$ is $-70 mV$.
#
# (I) The synaptic current induced by stimulation of pathway A is
# investigated under voltage clamp conditions at different
# membrane potentials The current is (inward, outward, no current)
# at the following holding membrane potentials : -80, 0, +40 mV
# -80 mV:
# 0 mV :
# +40 mV.
#
# (II) The part of the synaptic current carried by sodium ions is
# (inward, outward, no current) at -100, 0, +70mV:
# -100 mV:
# 0 mV
# +70 mV:
#
# (III) The part of the synaptic current carried by potassium ions is
# (inward, outward, no current) at: -100, 0, 70 mV:
# -100 mV:
# 0 mV
# +70 mV:
#
# (IV) Do NMDA channels contribute (yes, no) to the synaptic
# response evoked at
# -80mV:
# +40 mV:
# Briefly support your response and explain the consequences for
# the synaptic response.
#
# (V) Which is the expected reversal potential of the synaptic
# current evoked by activation of pathway B? Explain in one line .
#
# (VI)-The amplitude of the EPSP evoked by stimulation of
# pathway A under current clamp conditions at -70 mV is 10 mV.
# When both pathways are stimulated simultaneously the response
# is (the same, smaller, bigger)? Support your response briefly.
#
# (VII)-TTX applied to the bath will have the following effect in
# Synaptic responses evoked by stimulation of pathway A:
# Synaptic responses evoked by stimulation of pathway B:
# Mini EPSPs:
# Mini IPSPs:
# Briefly support your response.
#
# (VIII)- If a substance is applied that slows down the repolarization
# of action potentials invading the synaptic terminal, which effect
# will this have on :
# Evoked PSPs:
# MiniPSPs:
# Briefly support your response.
#
# (IX)-In current clamp conditions stimulation of the pathway A with
# a high frequency tetanus evoked the following effects: aImmediately after the tetanus the amplitude of the EPSC recorded
# at -70 mV was 300% the control amplitude (100% = no change).
# b-After 40 minutes the amplitude of the EPSC was 150% of the
# control amplitude.
# Which mechanisms, processes, explain the change in amplitude
# observed immediately after the tetanus and after 40 minutes.
# Detail concisely the known underlying mechanisms and name
# these phenomenons.
#
# (X)-When both pathways were stimulated (A and B) with a high
# frequency tetanus the following effects were observed. aImmediately after the tetanus the amplitude of the EPSC recorded
# at -70 mV was 300% the control amplitude (Same effect than
# stimulation of pathway A alone)). b-After 40 minutes the amplitude
# of the EPSC returned to the control amplitude. Provide an
# explanation for the differences in outcome observed when only
# pathway A or when both pathways are activated

# %% [markdown]
# ### Homework questions: Neural coding
#
# 1.	Which methods in neurobiology are useful to monitor neural activity in dendrites?
# >  Patch clamp (whole cell in current clamp) , Calcium imaging (partly).
#
# 2.	Explain why an action potential recorded extracellularly typically displays a negative deflection.
# > During AP the current inside the neuron goes from soma to axon terminal, whereas outside the cell the current is goes in the opposite dirrection (to close the loop). So when there is influx of $Na^+$
# > In dendrites different picture (first positive, that negative because of $K^+$)
#
# 3.	What is the relationship of the negative deflection (see question 2) to depolarization/hyperpolarization of the neuron?
# > So during depolarization we see **negative** current **outside** the cell, then during hyperolarization we the **positive** current **outside** the cell
#
# 4.	 Which frequencies in LFPs display correlation across long distances within neocortex – why?
# > Low frequencies in LFPs. Because **huge** number of neurons (networks) **sinchroniously** fire together (the size of generator is big) [Hypo that Tishue is low pass -  filter is wrong (checked directly)]
#
# 5.	Applying suprathreshold positive charge close to an **axon** is assumed to generate two action potentials in this fiber – why? [different]
# > Extracellulary: so this positive charge will cause negative charge in the same point
# > Intracellulary: inverse picture, so we have point with positive charge in axon -> activation of voltage-dependent channels  AP in two direction
# > <img  src="./images/tut1.png" width=700/>
#
# 6.	How can one measure the response of a pyramidal tract cell in motor cortex to electrical stimulation?
# > - We can not stimulate and record [extracellular] at the same time. So we stimulate from the different direction, and than record in 10 ms (time needed to travel from spinal cord to the cell.)
# > We can measure the **presence or absence of the responce** using additional strong stimulation in spinal cord (to send AP in other direction). So we can apply different stimulations to pyramida; tract cell and simulteniously strong stimulation in spinal cord If **there is AP (in the right direction)** we'll **not record AP in the different direction** because they will crash eash other.
#
# 7.	Why is the chronaxie in somas so much longer than in axons?
# > Because we have different shape of axons (they are like cables) and this different geomentry imply different $R, C$ and longer time constant $\tau=RC$ that is **correlated** with chronaxie
#
# 8.	What is the major caveat when using electrical stimulation to map out the representation of movements in motor cortex
# >The majour problem is that we stimulate axons in some location not somas (because typical stimulation time is $500 \mu s$ that is much less that soma's chronaxie.) So we are lacky that more axon that we stimulated ended in the near stimulation region not far from the point that we stimulate.
#
# 9.	In 2 photon microscopy all photons generated are captured by a photomultiplier. With conventional confocal (one photon) technology, only those photons that enter through a pinhole are captured. Why?
# > Because in confocal microscope we have get signal from the big volume of tischue, so if we what to see signal from some special point we have to use pinhole to not see all other signals, whereas it the 2 photon microscope we exite only small part of tishue (because probability of absortion of **two** photons is non zero only in point were all red light are concentrated (phocal plane))
# ><img  src="images/Diagram_of_a_two-photon_excitation_microscope_en.svg" width=400/>
#
# 10.	Why is it difficult to resolve cellular elements (soma, dendrites, axons) with voltage sensitive dyes. Why is it possible with calcium dyes?
# > - VSD are lipofilic
# > - Because VSD are stain **all** surfaces of all cells they are applied to. So we don't have special geneticly encoded VSD to stain only one cell, for example. With calium dyes we can incert them only in one cell, or genetically encode, so only special cells (or cell types) have stained.
# > - VS **genetically** encoded (proteins from voltage dependent channels)
#
# 11.	How can information be measured?
# > [Use mutual information of white noise and 'frozen' white noise ](../neurophisiology/neurophysiology.ipynb#l8p3)
#
# 12.	Imagine an electrophysiological experiment using tactile stimuli and recording units in a somatosensory neuronal structure. The experimental variable is the amplitude of skin indentation generated by a programmable stimulator that deflects the skin at variable waveforms using a mechanical probe. Describe a first experiment that measures the amplitude tuning curve of the recorded unit and a second alternative experiment that measures the response triggered stimulus ensemble.
# > 1. Apply the special stimulus, that you think can activate your neurons in SS. Look for the responce (typicly average response).
# > 2. Apply random waveforms many times. Use time window $T$ to go throuth all recodred spikes. Take all waveforms that caused 1 AP and average them. Do the same with 2, 3, ... AP.
#
# 13.	Draw a plot of a typical **tuning curve** and a typical **response triggered average**
# > <img  src="./images/tut2.png" width=600/>
# > I think the difference is only in axes
# > 1. - **response** triggered average: (x-axis is re, for example **spike count rate**) (y-axis is averaged stimulus , for example average speed)
# >    -  **spike** triggered average: (x-axis is **time**) (y - average responce as a function of time)
# > 3. tuning curve: (x-axis is different stimulus) (y-axis is response, for example averaged **firing rate**)
#
# 14.	What is a spike count rate
# > We cound number of spikes in some time interval, and average this number between trials. Then devide by the length of this interval to get average frequency. SCR **desctibe time interval**, not time points in this interval. $$r=\frac{\sum_{trials} n_i}{T}$$
#
# 15.	Describe in words which different mechanisms describe the spatiotemporal spread of voltage in a cable
# > 1. Ohm's low along x axis (so we have voltage attenuation)
# > 2. The **current** difference between $x$ and $x+ \delta x$ points are current that goes thouth membrane (Kirgophs current low)
# > 3. There is two elements cirquit including condactance and capacitor abd the sum of the voltage throuth this $RC$-circuet is equal to zero (Kirgophs voltage low)
#
# 16.	Exponential functions appear in dynamics of intracellular potentials in spherical cells and infinitively long cables. Explain how and why!
# > When we solve first order differential equation we get exponential solution.
# > The passive signal propagation in time and space is often exponential attenuation.
# > capacitive current, and attenuation in space
# 17.	Two excitatory synapses (glutamate AMPA receptors) are located on the same dendrite. There are no active conductances. What is the effect of conjunct activation compared to single EPSPs in the postsynaptic dendrite/soma?
# > nonlinear because o
# > It will be only **linear** summation of EPSP, because we don't have any active (voltage dependent ) elements that will be active due to this summation
#
# 18.	Same situation as in the last question but with additional NMDA receptors. How could this change the picture and why?
# > If the sum current is big enough we can pre depolorize NMDA enouph to get rid of $Mg^{2+}$ block and will activate NMDA -> will have additional depolarization and our EPSP will be bigger than linear sum of two EPSPs. In addition, if there are other NMDA channels in the same branch, and sufficient glutamate (to bind to these receptors) we can obtain [NMDA spike](./neurophysiology.ipynb#NMDAspike)
#
# 19.	How do calcium conductances in apical dendrites solve the problem of dendritic attenuation?
# >Stimulation in the apical dendrite generates calcium plateaus that propagate to the soma and trigger bursts of spikes. Calcuim plateau will propagate to the soma because it is not attenuated (there is enouth charge to charge capasitance and to propagate trouth dendrite)
#
# 20.	This is an $I-V$ state space spanned by membrane potential ($V$ in $mV$) and membrane current ($I$, arbitrary units) of a hypothetical neuron. The red $I-V$ curve represents the voltage and time independent potassium leak current $I_{leak}$. In addition to Ileak our imaginary neuron possesses the two fast voltage and time – dependent sodium (INa) and delayed rectifier ($I_K$) conductances that usually generate the spike. In part C the task is to draw the (approximate) $I-V$ trajectory of a spike. Before doing that
# 	- imagine the $K$ channel would be stripped of its voltage and time dependence leading to an increased potassium leak current (the $I$ axis in our plot is in arbitrary units: for simplicity let us assume the leak current would be doubled). Draw the $I-V$ curve of this hypothetically increased leak current $2I_{leak} = I_{leak} + I_{K,leak}$.
#
#     - Next, imagine the same for the $Na$ channel. The result would be a sodium leak channel ($I_{Na,leak}$. Draw the $I-V$ curve of this hypothetical channel into the graph (as the imagined channel would be a passive conductance we assume a linear $I-V$ curve; $[Na^+]_{out} = 140 mM, [Na^+]_{in} = 7 mM$). Then draw the combined $I-V$ curve $I_{K,leak} + I_{leak} + I_{Na,leak}$
#
#    -  Now consider a more realistic set of conductances, where in addition to the potassium leak current (red line), the sodium and delayed rectifier conductances that generate the action potential are present and show their typical voltage and time dependences. The sodium channel is activated at -50 mV and is rapidly deinactivated. The potassium channel is activated at -40 mV and is deactivated much slower compared to the sodium channel. Aided by the two curves you added in part A and B (IK,leak + Ileak and IK,leak + Ileak + INa,leak), draw the approximate I-V trajectory of a spike generated by intracellular injection of depolarizing current starting from rest and ending when the potential reaches rest again after the spike. The spike reaches a maximum of 20 mV.
