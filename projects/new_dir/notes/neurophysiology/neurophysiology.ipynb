# %%
from IPython.display import YouTubeVideo
from datetime import timedelta

def insert_video(video_id, start=0, end=0):
    if (start==0)and(end==0):
           return YouTubeVideo(video_id,width=600, height=400)
    #TO DO: use link "https://www.youtube.com/watch?t=19&v=WwoTzvOkEJQ" to get the id
    start_seconds=int(timedelta(hours=start[0], minutes=start[1], seconds=start[2]).total_seconds())
    end_seconds=int(timedelta(hours=end[0], minutes=end[1], seconds=end[2]).total_seconds())
    return YouTubeVideo(video_id,width=600, height=400,start=start_seconds,end=end_seconds)

from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# * [Lecture 1. Membrane voltage](#l1)
#     * [Part 1. Nernst Equation](#l1p1)
#     * [Part 2. GHK Equation](#l1p2)
#     * [Part 3. Pumps](#l1p3)
#
#
# * [Lecture 2](#l2)
#
#     * [Part 1. Transporters](#l2p1)
#     * [Part 2. Basic recording techniques](#l2p2)
#     * [Part 3. Membrane capacitance](#l2p3)
#
# * [Lecture 3](#l3)
#
#     * [Part 1. Current-voltage relationships](#l3p1)
#     * [Part 2.  Mollecular structure and function of ion channels](#l3p2)
#     * [Part 3. AP Generation ](#l3p3)
#
#
# * [Lecture 4](#l4)
#     * [Part 1. Introduction](#l4p1)
#     * [Part 2.  Quantum release](#l4p2)
#     * [Part 3. Culcium in NT ](#l4p3)
#     * [Part 4. Molecular mechanism of NT. ](#l4p4)
# * [Lecture 5](#l5)
#     * [Part 1. How NT cause EPSP](#l5p1)
#     * [Part 2. Molecular mechanism](#l5p2)
#     * [Part 3. GABA and Glutamate receptors ](#l5p3)
#     * [Part 4. Electrical synapse](#l5p4)
#
# * [Lecture 6](#l6)
#     * [Part 1. Introduction](#l6p1)
#     * [Part 2.  Long term synaptic plasticity](#l6p2)
#     * [Part 3. Sort term synaptic plasticity ](#l6p3)
#
# * [Lecture 7](#l7)
#
#     * [Part 1. Unit recording ](#l7p1)
#     * [Part 2.  Multiunit recording](#l7p2)
#     * [Part 3. Local field potential](#l7p3)
#     * [Part 4. Microstimulation](#l7p4)
#     * [Part 5. Optogenetics](#l7p5)
#     * [Part 6. Calcium imaging](#l7p6)
#     * [Part 7. Voltage sensitive dyes imaging](#l7p4)
#
# * [Lecture 8](#l8)
#
#    * [Part 1. Primer information theory ](#l8p1)
#    * [Part 2. Decoding and encoding ](#l8p2)
#    * [Part 3. Estimating information flow in neuronal pathways ](#l8p3)
#
#
# * [Lecture 9](#l9)
#   * [Part 1. Cable theory ](#l9p1)
#   * [Part 2. Computation using passive properties ](#l9p2)
#
# * [Lecture 10](#l10)
#   * [Part 1.Spike propagation ](#l10p1)
#   * [Part 2.Dendritic integration](#l10p2)

# %% [markdown]
# ## Block 1
# <a id='l1'></a>
# ### Lecture 1
#
# <a id='l1p1'></a>
#
# #### Part 1. Nernst Plank Equation
# *	The definition and main characteristic of ion channels.
# *	Nernst Plank Equation. [ND. Lecture 2. Part 1 ](..\Neural Dinamics\Lectures\ND.ipynb)
#
# >    $$j_{A}=-Fz_AD_A \left (\frac{d[A]}{dx}+\frac{F}{RT} z_A  [A] \frac{dV}{dx}\right )$$
#
# *	Nernst potential. [ND. Lecture 2. Part 1 ](..\Neural Dinamics\Lectures\ND.ipynb)
#
# >    $$E_{ion}=\frac{RT}{zF}\cdot \log\left(\frac{[A]_{out}}{[A]_{in}}\right)$$
#
# *	Apply Nernst Equation in different cases
#
# <a id='l1p2'></a>

# %% [markdown]
# #### Part 2. GHK equation
# *	Assuming **constant membrane potential V** and **independence of different ion types** one can derive current density  or Goldman-Hodgkin-Katz (GHK) current equation:
#
#        $$j_A=P_Az_AF\frac{z_AFV}{RT}\left ( \frac{[A]_{in}-[A]_{out}\cdot \exp{\frac{-z_A FV}{RT}}}{1- \exp{\frac{-z_A FV}{RT}}}\right) $$
#
#
# *	Setting **net current to 0**, compute the equilibrium potential Goldman-Hodgkin-Katz (GHK) voltage equation:
#
#         $$E_m=\frac{RT}{F}\ln \left (\frac{P_{K^+}[K^+]_{out}+P_{Na^+}[Na^+]_{out}+P_{Cl^-}[Cl^-]_{in}}{P_{K^+}[K^+]_{in}+P_{Na^+}[Na^+]_{in}+P_{Cl^-}[Cl^-]_{out}}\right)$$

# %% [markdown]
# #### Part 3. Pumps
# <a id='l1p3'></a>
# *	$Na^{+}-K^{+}$ pump (Sodium-Potassium Pump) – it is kind of **active** transport in the sense that cell use energy that is stored in **ATP** [CMN]  to move $Na^+$ and $K^+$ ions **against** their gradient. In this specific pump 3$ Na^+$ are going **out**, where as 2 $K^{+}$ are going **in**.
# *	Other main pump is Ca$^{+}$$^{+}$ pump (remove Ca from intracellular space)

# %% [markdown]
# <a id='l2'></a>
# ### Lecture 2
#
# <a id='l2p1'></a>
# #### Part 1.Transporters
#
# >    Transporter is transmembrane protein that allows exchange or cotrasnport of some ions, using energy of concentration gradient of one of the channels
#
# *	What are the condition when transporter is working properly?
# >    They will work properly only if there will be concentration gradient, so only if Na$^+$K$^+$pumps work properly.
#
# *	Describe the work of system of NKCC, KCC, and Na$^+$K$^+$pump.
# >1.	We can not use  NKCC  to remove Cl, because we have small Na inside cell, and the moving of all elements is in the same direction. So we use this transporter in the opposite direction
#  2.	Now we have **additional Na** in cell (witch will be removed by Na-K pump and will give as **more K**) and **additional K** from NKCC
#  3.	If we try to use only KCC, than the Cl concentration is linked to K concentration
# > $$P(K^+ + Cl^- \text{go inward})= P(K^+ \text{bind outside}) \cdot P(Cl^- \text{bind outside})\propto [K^+]_{out}\cdot [Cl^{-}_{out}]=[Cl^-]_{in}\cdot [K^{+}_{in}] \propto  P(Cl^- \text{bind inside})\cdot P(K^+ \text{bind inside})=P(K^+ + Cl^- \text{go outward})$$
#  4.	Only with these two cotransporters we can  vary the $[Cl^-]_{in}$.
# *	Due to different temp of expression of NKCC and KCC proteins, we first have $E_{Cl}$ potential that is less that $E_{GHK}$, and therefore the GABA$_A$ receptor is **excitatory**. After 15 days we have more KCC2 transporter expressed and smaller Cl concentration inside $\rightarrow$ smaller E$_{Cl}$ $\rightarrow$  $E_{Cl} < E_{GHK}$ $\rightarrow$  R GABA$_A$ is inhibitory (to CMN)
# *	Describe how it effects development
# *	Describe Reuptake and vesicular accumulation of glutamate (CMN)

# %% [markdown]
# <a id='l2p2'></a>
#
# #### Part 2. Basic recording techniques
#
# *	Difference between current clamp and voltage clump
# > In **current clamp**, we simply give some current pulse (can be zero), and then record voltage.
# > In **voltage clamp**, our aim is to get the constant voltage. So we can calculate what current $I(t)$ we have to inject to obtain the voltage $V_0$.
#
# *	Describe the patch clamp technique and different configurations (NET)
# *	Describe three applications of voltage clamp recording: ST, Single channel recording, Voltage dependent gating of membrane conductance.
# > 1. We get that $g_{syn}$ is **time dependent** and that $j_{syn}=g_{syn}(V-E_{syn})$
# > 2. In patch clamp
# > 3. For example, H-H experiment

# %% [markdown]
# <a id='l2p3'></a>
#
# #### Part 3. Membrane capacitance [ND. Lecture 2. Part 1 ](..\ND\Lectures\ND.ipynb)
#
# *	Describe the formula for capacitance, A and d dependence.
# >$C=\frac{\epsilon_0 A}{d}$
# *	Describe the time properties of voltage decay, time constant.
# >Simply look at solution of passive membrane model, time constant is $\tau=RC$

# %% [markdown]
# <a id='l3'></a>
#
# ### Lecture 3. Ion channels
#
# <a id='l3p1'></a>
# #### Part 1. Current-voltage relationships
#
# * $P_{o}= \frac{Rate_{CO}}{Rate_{CO}+Rate_{OC}}$
#
# * $I_{mean}=(E_m-E_{NP}) \cdot g_{open} \cdot P_{o} \cdot n_{chanels} $
#
# * Describe the changes in $V-I$ graph if we change $E_{NP}$ or $g_{open}$
# > When we change $E_{NP}$  our line will move left or right.
# >
# > When we change $g_{open}$ our line will rotate respectively to the $E_m=E_{NP}$ point
# > <img  src="images/l3p1g1.png"/>

# %% [markdown]
# <a id='l3p2'></a>
# #### Part 2. Mollecular structure and function of ion channels (NET)
#
# * Voltage depended channels
#
# > Voltage dependence - changing of membrance potational,that induce some changes in ion channel conformation
#
# > * K
# > * Na - main difference that it also has inactivation lid
# > * Ca. Different types of Ca$^{++}$ voltage depended channels
#
# >  1. L-type: high threshold  and slow inactivation, high single condactance
# >  2. T-type: small threshold, small single condactance
# >  3. N-type: fast activation and inactivation
# >  4. P,R, Q-type the same function as N-type, but different pharmacological properties

# %% [markdown]
# <a id='l3p3'></a>
#
# #### Part 3. AP Generation (ND)
#
# * Describe the methon that H-H used to understand AP.
#
# * What are substitutions experiments?
#
# * Describe the results of these experiments:
#
# > 1. Depolatization above threshold
# > 2. Na condactance is increasing
# > 3. 1. Na condactance is inactivated,
# >    2. K condactance is activated with delay
# > 4. K condantance persists

# %% [markdown]
# <a id='b3'></a>
# ## Block 2. Synaptic transmission

# %% [markdown]
# <a id='l4'></a>
#
# ### Lecture 4. Presynaptic mechanisms (How AP triggers the release of a neurotransmitter )
#
# <a id='l4p1'></a>
# #### Part 1. Introduction
#
# Synapse - contact between neurons or between neurons and effectors ( muscle fibers) specialized in transmitting signals.
#
#  - Electrical vs Synaptic transmission
#
#  **Otto Loewi**
#  <img  src="images/l4g1.png"/>
#
#  > Neuromuscular junction (synapse):
#  >  - Big
#  >  - Secure (each AP $\rightarrow$ response: EPSP or EPP -depolarizations of skeletal muscle fibers)
#  >  - Neurotransmitter: Acetylcholine
#
#  In CNS:
#   1. Presynaptic side (synaptic terminal, bouton)
#   2. Synaptic cleft ($20 nm$)
#   3. Postsynaptic side.
#
# - Electrical vs Synaptic transmission (in voluntary system)
# We can see *minimum synaptic delay*
#  <img  src="images/l4g2.png"/>

# %% [markdown]
# <a id='l4p2'></a>
# #### Part 2. Quantum release
#
# **Neurotransmitter is released in quantums**
#
#  <img  src="images/l4g3.png"/>
#
#  mepps (minis) - very similar to EPSP:
#    - Amplitude decreased with distance (so they are created locally **in synapse**)
#    - Same wave form
#    - Blocked by blockers of $AcCh$
#    - mepp size = 1000s of AhCh (so it is not leak of single $AcCh$)
#
#  Observation: EPP is proportional to MEPP (can be seen in low $[Ca^{++}]$ )
#
#  <img  src="images/l4g4.png"/>
#
#  These observations lead us to quantal hypothesis.
#
#  Later analysis: $M=np$, where
#
#  $M$ - quantal content,mean **number** of quantums per AP
#  $q$ - quantal size, **response to one quantum**
#
#  - via EM one can see vesicles

# %% [markdown]
# <a id='l4p3'></a>
# #### Part 3. Calcium in NT
#
# ** Probability of release $p$ increases via $Ca^{++}$ influx**
#
# We use large **pre-synaptic** fiber of SQUID
#
# >Experiment: block of $Na$ influx (also can block $K^+$)
#  <img  src="images/l4g5.png"/>
#
#  - We see that AP is important in ST.
#
# >Experiment: induce **different** current when $Na$ is blocked
#   <img  src="images/l4g6.png"/>
#
#  -  The increase of **pre-synaptic** current correlates with increase of post-synaptic current. There is threshold ($V_{threshold}=50 mV \geq V_{AP}$)
#  - *Is this threshold is the $V_m$, when calcium voltage dependent channels are opened?*
#
# > Experiment: $Ca^{++}$ **and** Depolarization is necessary.
#  <img  src="images/l4g7.png"/>
#
#  -  **AP activate voltage dependent calcium channels $\rightarrow$ calcium influx $\rightarrow$ increase in probability of NT release. **
#
# Observation:
#
#  Spontaneous release of quantums is not abolished by low calcium
#
# > Experiments: direct demonstration of calcium influx
#
# > Calcium sensitive dye
#  <img  src="images/l4g8.png"/>
# - time course of the light is slower that the changes in calcium
#     concentration.
#
#
# > Voltage clamp of presynaptic terminal+TTX+TEA
#  <img  src="images/l4g9.png"/>
# - we also use $Ca^{++}$ blockers (b) to see that there is no current under blocked $Ca^{++}$ channels
#
#
# Observation:
#
# When we apply big pulse (such that we change membrane voltage to 120 mV) our influx of $Ca^{++}$ will be small because we near Nernst potential of $Ca^{++}$ ($V_{Ca}=+129 mV$), but the **amount of open channels will increase**, when we end our pulse, membrane voltage will goes down and driving force $g(V_{Ca}-V_m)$ will go up, so we see influx of $Ca^{++}$
#
# >Experiment: Finding of the shape of calcium influx current
#  <img  src="images/l4g11.png"/>
# 1. record the waveform of AP
# 2. block $Na^+$ and $K^+$ record the current under voltage clump at the same waveform (*How do we do voltage clump at some waveform?* )
# 3. additionally block $Ca^{++}$ and do the same
#   - the difference between 2 and 3 will be calcium signal
#
#
# Observation:
#  Calcium influx occurs during **repolarization** and have a **fast rise**.
#
#  Timing of ST
#   <img  src="images/l4g12.png"/>

# %% [markdown]
# <a id='l4p4'></a>
# #### Part 4. Molecular mechanism of NT. How does calcium change the probability of release (how does it induce the release of NT )?
#
# <img  src="images/l4g13.png"/>

# %%
insert_video('iNaOwRjEf1M',(0,3,30),(0,8,45))

# %% [markdown]
# - Here priming is **SNARE Complex** formation and fusion is  $Ca^{2+}$ binding by **Synaptotagmin**
# <img  src="images/l4g14.png"/>
#
# > Experiment: Role of synaptotagmin in NT
# <img  src="images/l4g15.png"/>
#
# - Knock out of synaptotagmin blocks EPSP. (only spontanius minis are create small changes in EPSP)
#
#
# There are several options of positions of $Ca^{2+}$ sensors and $Ca^{2+}$ voltage gated channels:
#  - they can be located near each other (nanodomain)
#  - or far away from each other
# Observation: fast and slow buffers, react differently to $Ca^{2+}$ influx
# <img  src="images/l4g16.png"/>
#
# Minis: **in some cases** release of minis is due to spontaneous flux of calcium through calcium channels, due to
# spontaneous openings

# %% [markdown]
# <a id='l5'></a>
#
# ### Lecture 5. Postsenaptic mechanisms : a chemical to electrical transduction
#
# <a id='l5p1'></a>
# #### Part 1.  How NT cause the EPSP.
#
#  Observation:
# > - Signal is local
# > - molecules of $AcCh$ work only on synapse site, so only there is something that react to $AcCh$
# > <img  src="images/l5g1.png"/>
#
#  Tree hypotheses:
# > - **$AcCh$ opens specific or *unspecitic* ion channels**
# > - $AcCh$ lowers the resistance (shunts the postsynaptic membrane)
# > - $AcCh$ permeates the membrane
#
#  Calculation:
# > The number of $AcCh$ molecules to induce EPSP is **bigger** then the number of molecules in axon terminal $\Rightarrow$ third hypothesis rejected.
#
# Experiment:
# > Specific or *unspecitic* ion channels by voltage clump
# > <img  src="images/l5g2.png"/>
# > the *reversal potential* of **is not equal** to one of Nernst potential $\Rightarrow$ several ions permeate this channel
#
# Experiment:
# > Changing concentration of ions
# > <img  src="images/l5g3.png"/>
# > <img  src="images/l5g5.png"/>
# > the changing concentration of $Na^+$ and $K^+$ change reversal potential linearly, whereas $Cl^-$ doesn't affect reversal potential $\Rightarrow$ shunting hypothesis rejected.
#
#
# Experiment:
# > Patch recording of one channel (to check is it *one unspecific* or several specific channels involved in ST)
# > <img  src="images/l5g6.png"/>
# > - there is no current at $0 mV$ (the reversal potential)
# > - this reversal potential is not equal to Nerst potential of one of ions, so there is current of several ions  $\Rightarrow$ channel is unspecific
#
# Experiment:
# > Voltage clump to look at conductance of this channel
# > <img  src="images/l5g7.png"/>
# > Peak synaptic current is lineary depends on $V_m$,
#
# > so in $I=g_{syn}(V)(V-E_{reversal})$, $g_{syn}(V)=g_{syn}$ is constant
#
# Summary:
# > - $AcCh$ opens *unspecitic* cation channels
# > - They have *constant* conductance

# %% [markdown]
# <a id='l5p2'></a>
# #### Part 2. Molecular mechanism of chemical to electrical transduction
#
# $AcCh$ receptor
# > <img  src="images/l5g8.png"/>
# > M2 domain of 5 subunits create a pore.
# > <img  src="images/l5g9.png"/>
# > Pore is permeable to cation due to 3 rings of negatively charged aminoacids.
#
# > <img  src="images/l5g10.png"/>
# > Model of conformational change( opening of channel)
#
# Observation:
# > The time course of current and voltage is different.
# > <img  src="images/l5g11.png"/>
# > The delay in EPSP is due to **time to charge** capacitance
# > <img  src="images/l5g12.png"/>
#
# Metabotropic receptors
# > - Work indirect and slow
# > - Can open and **close** open in resting state channels
# > <img  src="images/l5g13.png"/>
#
# Inhibitory and excitatory synapse
# > - The synapse is inhibitory when the *reversal potential* of the channels in this synapse is less than *threshold of AP* in postsynaptic cell. ($V_{reversal}<V_{AP threshold}$)
# > - The synapse is excitatory when the *reversal potential* of the channels in this synapse is bigger than *threshold of AP* in postsynaptic cell. ($V_{reversal}>V_{AP threshold}$)
#
# Shunting inhibition
# >  if the inhibitory synaptic reversal potential is identical to the resting potential, then the effect of EPSP **and** IPSP will be less due to flux of $Cl^-$ in the opposite direction to current that induce EPSP and IPSP.
# > <img  src="images/l5g14.png"/>

# %% [markdown]
# <a id='l5p3'></a>
# #### Part 3. GABA and Glutamate receptors
# GABA receptor
# > GABA A can be modulated (i.e. change their conductance) by other substances (via benzodiazipine)
#
# > GABA A - ionotropic, GABA B - metabotropic. So the effect of GABA NT is explained by the combination of activation of GABA A and GABA B
# > <img  src="images/l5g15.png"/>
#
# <a id='NMDA'></a>
# Glutomate receptor: AMPA, NMDA,Kainate receptors
# > The $V$ has additional slow component in more depolorized stage ($V=-40 mV$) (So the response is voltage depended)
# > <img  src="images/l5g16.png"/>
# > The shape of different components is due to different receptors (AMPA and NMDA)
# > <img  src="images/l5g17.png"/>
# > Difference in response during depolarization and hyperpolarization is due to $Mg^{++}$ blocking of channel during hyperpolarization.
# > <img  src="images/l5g18.png"/>
# > During hyperpolarization we see flickering (fast opening and closing of channel)
# > <img  src="images/l5g19.png"/>

# %% [markdown]
# <a id='l5p4'></a>
# #### Part 4. Electrical synapses
# Evidence
# > **No delay** between pre and post synaptic current
# > <img  src="images/l5g20.png"/>
# > Double patch of two cell that have electrical synapse
# > <img  src="images/l5g21.png"/>
#
# Gap junction
# > <img  src="images/l5g22.png"/>

# %% [markdown]
# <a id='l6'></a>
# #### Lecture 6. Synaptic plasticity
#
# <a id='l6p1'></a>
# #### Part 1. Introduction
#
# Synaptic strength - mean postsynaptic response to the presynaptic AP.
#
# Plasticity - change in synaptic strength
#
# Pre-synaptic: $M=np$, where
#
#  - $M$ - quantal content,mean **number** of quantums per AP
#  - $p$ - probability to release
#
# Post-synaptic:
#  - $q$ - quantal size, **response to one quantum**
#
# So the synaptic strength is equal to $npq$
#
# To be more biologically precise one can use:
#  - $p_{release}$
#  - $p_{fuse}$ - depends on $Ca^{2+}$ concentration near the vesicle (so location of vesicle plays role)
#
# Where us $q$ is depends on:
#  - number of receptors (in saturated regime)
#  - synaptic conductance of receptor
#  - time with channel remains open
#  - number of molecules in one quantum (in unsaturated regime)
#
# Estimation of quantal content $M$
# > - Assume that synapses sum linear
# > - Assume that the content of minis vesicles is identical to the content of ordinary vesicles.
# > - $M=\frac{\text{average size of EPSP}}{\text{average size of minis}}$
#
# Vesicle imaging
# > Synaptophluorin, is a molecule **Ph sensitive**. Whe Ph is changing it has conformational change $\rightarrow$ change it **fluresense**
# > <img  src="images/l6g1.png"/>
# > <img  src="images/l6g2.png"/>
#
# Calcium imaging
# > Some synaptic channels are permeable to calcium, so the amount of calcium in postsynaptic site can indicate NT
# > <img  src="images/l6g3.png"/>

# %% [markdown]
# <a id='l6p2'></a>
# #### Part 2.  Long term synaptic plasticity
# Long term potentiation
# > <img  src="images/l6g4.png"/>
#
# > Hippocampus lesions led to loss of memory, so LTP is connected with memory.
#
# > Properties:
# > - specificity (only activated synapse modified)
# > - associativity (association of many inputs are necessary to trigger LTP )
# > - persistency (long time effect)
#
# > Block of NMDA receptors prevent **induction** of LTP (whereas response to single pulse is unchanged )
# > <img  src="images/l6g5.png"/>
#
# Mechanism of LTP induction
# > Activation of NMDA receptors requires sufficient depolarization (to remove $Mg^{2+}$)
# > <img  src="images/l6g6.png"/>
# > Influx of $Ca^{2+}$ due to activation of NMDA receptors is important
#
# Mechanism and location of LTP expression
# > Early phase
# > <img  src="images/l6g7.png"/>
#
# > Late phase. Requires **new protein synthesis**
# > <img  src="images/l6g8.png"/>
# > <img  src="images/l6g9.png"/>
#
# STDP (the same internal mechanism caused by casual activation of two neurons synchronously)
# > <img  src="images/l6g10.jpg" width=300/>
# > ???

# %% [markdown]
# <a id='l6p3'></a>
# #### Part 3. Sort term synaptic plasticity
#
# STSP - the change in synaptic strength during second (miliseconds) from previous activity.
#
# One stimulation
# > <img  src="images/l6g10.png" width=300/>
#
# Train
# > <img  src="images/l6g11.png" width=300/>
# > This response can not be explained simply by summation of single responses.
#
# > There are several components of response that has to be generated by several different molecular mechanisms
# > <img  src="images/l6g12.png" />
#
# Molecular mechanism of STSP
# > Residual calcium (by calcium imaging)
# > <img  src="images/l6g13.png"/>
#
# > It is other sensor (not synaptotagmin) because of different **scale** and **form** of dependence
# > <img  src="images/l6g14.png"/>
#
# Functions
# > - Filtering (different response to the stimulus in different frequencies) $\rightarrow$ computations
# > - Synaptic dynamics can be different in different terminals (terminals that connected to different cell types) (so the same signal effect different neurons differently)
# > - Spacial-temporal transformation
# > - Selective reading (facilitating selective to average frequency, whereas depression selective to changes in firing rate), transfer of information
# > - Sensory processing (adaptation, habituation)

# %% [markdown]
# <a id='b3'></a>
# ## Block 3. Neural coding
#
# Information processing is going on in the dendritic tree, so EPSP and integration of different EPSP is more essential for information processing, than AP

# %% [markdown]
# <a id='l7'></a>
# ### Lecture 7. High spasial and temporal resolution - electrophysiology and imaging

# %% [markdown]
# <a id='l7p1'></a>
# #### Part 1. Unit recording
# * Intracellular recording
#
#     * Two electrodes: one inside the cell, other is reference electrode
#     * Big resistance ($R$ is in $G\Omega$)
#     * Isopotential (inside the cell)
#     * Easy to measure exact AP, and even other under threshold activity (EPSP without AP)
# * Extracellular recording
#     * Two electrodes: one is **near** the cell, other is away and can have different shape to be not influensed by other neuron activity
#     * Two shapes of output signal: near the soma, because of Na influx and than K outflux (-+) and near the dendrite, because of leak K channels (+-)
#     * Amplitude is 1000 less than in intracellular recordings
#     * In  Piramidal Cell it's easy to classify the output signal, but for diffenet shape it is not so clear

# %% [markdown]
# <a id='l7p2'></a>
# #### Part 2. Multiunit recording
#
# * Spike sorting:  threshold and alignment $\rightarrow$ PCA $\rightarrow$ clustering
# * The signal is reduced to time points of spikes of one neuron - spike trains
# * Raster plots: repeat the stimulus many times and align the trains

# %% [markdown]
# <a id='l7p3'></a>
# #### Part 3. Local field potential
#
# * We can filter the same data with low pass filter, so we will not see that high frequencies and AP. We will see that there is another signal (synaptic inputs, intrinsic membrane currents,
# network oscillations) that have low frequencies. It is signal from many neurons and it is called local field potential (LFP)
# * We can measure more neurons in smaller frequencies (How we measure amount of neurons that we can measure?)
# * In small frequencies, we see that **more neurons** activates simultaneously, and that is is the reason why we can record signal from many neurons.
# *  extent of the neuronal generator ???

# %% [markdown]
# <a id='l7p4'></a>
# #### Part 4. Microstimulations
#
# * You always induce AP, for positive carge - in near parts of the axon, in negative charge - in the part where you inject extracellular current
# * One more **case study**: How to measure **intensity threshold**.
#
#
# **The problem** is with the electrode that can only mesure of inject current in the soma, and that you can not find axon of the neuron you injected in.
#
# **The solution** is induse AP backward too all axsons, and than look for current when there will be so signal to the soma, because two AP encounter each other
#
# $$I(d)=I_0+\frac{I_0c}{d}.$$ Here d - is pulse duration, $I_0$- minimal pulse (rheobase), $c$-chronaxie (pulse length needed to
# reach threshold at $2I_0$)
#
# Describe this graph:
#  * What does threshold mean for recording?
# <img  src="images/p7p4g1.png"/>
#
# So we can see that charge $q=I_0d$ determins the AP. And therefore it is better to report $I_0$ and $d$, not simply $I_0$ or even $V$
#
# * There is correlation between $c$ and $\tau$. So $c$ changes when $\tau changes$
# * $c < 500 \mu s$ in axons, whereas $c \gg 500 \mu s$ in soma $\Rightarrow $ we stimulate AP in axons not in soma (when we stimulate with $c< 500 \mu s$) $\Rightarrow $ the sensory bady maps, are accidentally correct, because it is more **axons** connected to near soma than to the distinct soma

# %% [markdown]
# <a id='l7p5'></a>
#
# #### Part 5. Optogenetics
#
# * Opsins are a group of **light-sensitive** proteins found in photoreceptor cells of the retina.
#
# * There are diiferent proteins:
#  - cation channels (blue light)
#  - cloride pumps (yellow light)
#  - protein involved in transduction (depend)
#
#  We can inhibit\ excite or neurons by light
#  > <img  src="images/l8g1.png"/>
#
#  Diffeent proteins have different effect, activation color, kinetics (to that they are staying open)
#  > <img  src="images/l8g2.png"/>
#
#  - The optogenetics competible with electrophysiology
#  - in principle **allow the stimulation** of defined subsets of neurons (e.g. **single neurons**,
#    genetically defined **neuronal classes**, etc.)

# %% [markdown]
# <a id='l7p6'></a>
# #### Part 6. Two photon calcium imaging
#
# - The light (and energy in photons) destroy tissue, if it had **big energy**
# - So during imaging it is useful to use light with low energy (**red light**)
# - Two photon microscope use 2 red photons that have to be in the **same time** and **same location** to excite fluorophore
# > <img  src="images/l8g4.png"/>
# - The difference between confocal and 2-photon mircoscope is that *excitetion* can occur **only** in **focal plane**  $\rightarrow$ no pinhole and less *phototoxicity*
# - Near-infrared light penetrates **deeper into tissue** (we can record more)
#
# We use **calcium sensative** dyes. After reaction with $Ca^{++}$ they change their conformation and become **flurecent**
# > <img  src="images/l8g5.png"/>
#
# Then we image the cell and see the moments when it becomes flurecent $\rightarrow$ there is big concentration of calcium in the cell $\rightarrow$ there is AP (or several)
#
# > <img  src="images/l8g6.png"/>
# > The $Ca^{2+}$ is slower that AP, so we can't resolve some AP that occur near each other
#
# - Allows the investigation of **single neurons** (via intracellular
# fills) as well as **neuronal populations** (via bulk loading of
# tissue with **dyes that pass membranes**)
# - More **recent** approaches use **genetically encoded** calcium
# probes expressed in specific populations of neurons
# (depending on a promoter gene). Genetic modification is
# realized by **transgenic mouse** lines or transfection with
# **genetically engineered virus** technology.

# %% [markdown]
# <a id='l7p7'></a>
# #### Part 7. Voltage sensitive dyes imaging
# <img  src="images/l8g7.png"/>
# - Reports membrane potential at **excellent temporal
# resolution**
# - Stains all membranes in the vicinity of the application
# site. Is **not applicable to single cells**.
# - It only allows imaging of neuronal activity on a more
# **macroscopic scale**
# - **Genetically encoded** VSDI is in establishment. In the
# near future, it will **solve the problem to image single
# cells**.

# %% [markdown]
# <a id='l8'></a>
# ### Lectire 8. Encoding information using spiketrains
#
# - **What** is encoded? Which are the relevant stimuli that
# engage the neuron optimally?
# **Tuning curves/ Spike triggered stimuli**
# - **How** is information encoded? Is information contained in the
# number and/or timing of spikes?
# **Spike counts / Firing rate / Spike patterns**
# - **How precise** is the **representation**? How much information is conveyed?
# How is information affected by the
# presence of noise?
# **Information measures**

# %% [markdown]
# <a id='l8p1'></a>
# #### Part 1. Primer information theory
#
# Mutual information
# > <img  src="images/l8rg1.png"/>
# > Shannon information quantifies the deviation from **independence of two
# distributions**
# > <img  src="images/l8rg2.png"/>
# > Formulation througth **entropies**

# %% [markdown]
# <a id='l8p2'></a>
# #### Part 2. Encoding and decoding
# > <img  src="images/l8rg4.png"/>
#
# Responce trigerred averaging (Decoding)
# > - When we don't know what neuron is doing
# > - Take a response measure (spike, pattern etc.) and measure the stimulus that evoked it (typically taken from
# a white noise stimulus). So we **average white noise** using only such white noise stimulus that trigger firing of our neuron
# > - *So we want to find out what firing of our neurons mean* (Subject view)
# > - **finding the stimulus** parameters a neuron is ‘interested’ in
# > -  experimentally costly  (a lot of data to get good average)
#
# Tuning curve (Encoding)
# > - When we know what neuron is doing
# > - Control the stimulus experimentally and measure the evoked response
# > - *So we want to know the reaction in our brain on this stimulus* (Experementer's view)
# > -  fine details of the stimulus parameters a neuron is tuned to

# %% [markdown]
# <a id='l8p3'></a>
# #### Part 3. Estimating information flow in neuronal pathways
# - Direct estimation of information flow: Mutual information = Response entropy - Noise entropy
# > <img  src="images/l8rg5.png"/>
# > 1. Give long white noise and recored responce
# > 2. Look of probability of words $p(r)$ (for example '01001') in recorded responce (to estimate right probability of longer word you need more data)
# > 3. Calculate the entropy of the responce $H(r)$
# > <img  src="images/l8rg6.png"/>
# > 4. perform a very long experiment presenting ‘frozen’
# gaussian white noise (‘repeating trials of one and
# the same stimulus’) and record as many spikes as
# you can
# > 5. Calculate $p(r|s)$ (fraction of words in responce to 'frozen' white noise)
# > 6. Calculate average noise entropy $H(r|s)$
# > 7. $I =H(r)-H(r|s)$

# %% [markdown]
# <a id='l9'></a>
# ### Lecture 9. Information processing in dendrites and somas.  Passive properties
#
# Passive parralell $RC$-circle
#   ><img  src="images/l9g1.png" width=150/>
#   >$$V(t)=IR\left(1-\exp^{\frac{-t}{RC}}\right)=IR\left(1-\exp^{\frac{-t}{\tau_M}}\right)$$
#   >$\tau_M=RC$ is time constant

# %% [markdown]
# <a id='l9p1'></a>
#
# #### Part 1. Cable equation
# > <img  src="images/l9g3.png" width=500/>
# > Assumptions:
# > - Membrane [parameters](#par) are uniform
# > - Current flow along length $l$ of the cable – no radial flow ???
# > - Extracellular resistance is zero (outside the neurone the conductance $g_{outside}\rightarrow \infty$)
# >
# > Parameters:
# > <img  src="images/l9g2.png" width=400/>
# > <a id='par'></a>$r_i, r_M, c_M$ are parameters of our cable, we assure that they are not changing in space (to not depend on $x$)
# >
# > $r_i=\frac{R_i}{\pi a^2}$, so the bigger diameter of the axon the smaller $r_i$
# >
# > $r_m=\frac{R_M}{2\pi a}$, so the bigger the surface of membrane ($A=2\pi a l$) the smaller $r_M$
# >
# > $r_C=2 \pi a R_C$, so the bigger the surface of membrane ($A=2\pi a l$) the bigger $c_M$
# >
# > If we want to find total characteristics of cable that has length $l$:
# >
# > $$R_{i_{total}}=r_i l \quad R_{m_{total}} =\frac{r_m}{l} \quad C_{m_{total}} =c_m l$$
# >
# > Neuronal elements like axons and dendrites are *lousy (bad)*
# cables (So what?)
# >
# > We use Ohm's low along the $x$ axis to calculate *drop of voltage*, Kirchof's low to calculate change in $i_i$ and current flow in parallel $RC$-circuit
# > $$\frac{r_m}{r_i}\frac{\partial^2 V}{\partial x^2}=c_m r_m \frac{\partial V}{\partial t}+V_m$$
# > Space constant $\lambda=\sqrt\frac{r_m}{r_i}$
#
# Solutions to cable equation
# > Infinite cable at steady state ($L= \infty, T= \infty$)
# > <img  src="images/l9g5.png" width=400/>
# > $V_m(\infty,X)=V_0e^{-X}$
# >
# > Infinite cable ($L=\infty$)
# > <img  src="images/l9g6.png" width=400/>
# >
# > Finite cable, stable solution ($T=\infty$)
# > <img  src="images/l9g7.png" width=600/>
# > - **Voltage clamp** at the end of the cable is equivalent to the **open end** situation. Thus, recording in voltage clamp mode **alters the electrotonic properties** of the neuronal element under investigation
# > We can look for the speed of our solution
# > <img  src="images/l9g8.png" width=400/>
# > The speed of the point that is one half of the steady state solution $\theta=\frac{2\lambda}{r_m}=\sqrt {\frac{2a}{R_MR_i{C_M}^2}}$
# >
# > It is $\propto \sqrt a \Rightarrow$ **the thicker the cable the faster the conduction**

# %% [markdown]
# <a id='l9p2'></a>
# #### Part 2. Computation using passive properties
#
# Dendritic Delay Lines
# > Space: EPSP **amplitude** is
# determined by distance of
# synapse from the soma
#
# > Time: EPSP **latency** is
# determined by distance of
# synapse from the soma
# > <img  src="images/l9g10.png" width=400/>
# > <img  src="images/l9g9.png" width=500/>
# > So here the AP will be only in special sequence of EPSPs
#
# Local computations and non-linear interactions
# > 1. Driving force changing if EPSP and IPSP are near each other (on the same branch)
# >   $I_{ion}=g_{ion}\cdot(E_{ion}-V_{rest})$
# >
# >   $E_{Cl}$ is near $V_{rest}$. Assume that they are equal, then $I_{inh}=0$. But when we will have local depolarization due to EPSP $\Rightarrow I_{inh}=g_{Cl}\cdot(E_{Cl}-V_{depolorized})\neq 0$
# >
# > 2. Shunting inhibition - when the second channel are opened the whole current goes from first synapse to the second $\Rightarrow$ **nothing goes to the soma** (opened end model this effect)
# > <img  src="images/l9g11.png" width=500/>

# %% [markdown]
# <a id='l10'></a>
# ### Lecture 10. Active properties
#
#
# <a id='l10p1'></a>
# #### Part 1. Spike propagation
# > - To make AP faster $\rightarrow$ Myelinated axons
#
# >- Neuronal function is expressed in variable morphology
# - … and variable patterns of spiking
# <img  src="images/l10g1.png" width=500/>
# >
# >
# - There are several ion channels that produce different shapes of current
# <img  src="images/l10g2.png" width=700/>
# And can **modulate** the AP quite differently
# ><img  src="images/l10g3.png" width=700/>

# %% [markdown]
# <a id='l10p2'></a>
# #### Part 2. Dendritic integration
# > How active properties can help to overcame attenuation? (How to amplify the EPSP?)
#
# > What computations can we do with such active properties?
# ><img  src="images/l10g4.png" width=500/>
#
# Apical dendrite
# > Dendritic calcium spike
# > - **Stimulation in the apical dendrite generates calcium plateaus** that propagate to the soma and trigger bursts of spikes. **Stimulation in the soma triggers regular spike** trains that by themselves do not trigger calcium spikes.
# > - Cd2+, a **blocker of voltage dependent calcium channels changes burst firing to regular firing** indicating that indeed calcium is the carrier of this process
#
# > Backpropagating spikes
# > - **Distal** synaptic inputs that **alone do not trigger** a dendritic calcium spike (and thus have negligible effect on the somatic potential) **can do so if they occur in concert with an action potential *backpropagating* actively** from the soma
#
# Basal dendrite
# > Sodium spike - there are voltage dependent sodium channels in basal dendrites, that can be activated if there is backpropagation of AP, of big EPSP, or **two EPSP in the same place and time** (less then several ms)
# > <img  src="images/l10g5.png" width=800/>
# > <img  src="images/l10g6.png" width=400/>
# >
# <a id='NMDAspike'></a>
# > NMDA spike - creation of voltage plateau due to sufficient **depolarization** **and** sufficient **number of NMDA receptor** to create new stable point
# ><img  src="images/l10g7.png" width=600/>
# > Depending on number of activated NMDA (it depends on amount of glutamate in synaptic cleft) channels the neuron will return to resting potential, or (if the number of activated NMDA channel is big) to **new stable point** (plateau potential)
# ><img  src="images/l10g8.png" width=800/>
# The stable point (and its existence)  depends on number of activated NMDA receptors
